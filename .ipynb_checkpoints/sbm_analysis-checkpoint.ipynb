# %%
from bokeh.plotting import figure, show, output_notebook
# from bokeh.charts import Scatter, output_file, show
# from bkcharts import Scatter, output_file, show
from bokeh.palettes import Spectral6
from bokeh.layouts import gridplot, row, column
from bokeh.models import (
    HoverTool, BoxSelectTool, 
    LassoSelectTool, Spacer, 
    CustomJS, ColumnDataSource, 
    LinearColorMapper, BasicTicker,
    LogColorMapper,
    PrintfTickFormatter,ColorBar
)
from bokeh.models.widgets import Panel, Tabs

import matplotlib
import numpy as np
import pandas as pd
import scipy.stats

# %% [markdown]
# ## Overview

# %% [markdown]
# - [Plot q](#Plot-q)
# - [Q Histogram](#Q-Histogram)
# - [Plot distance histogram](#Plot-distance-histogram)
# - [WHAM results](#Wham-Results)
#     - [Free Energy vs. Q](#F-vs-Q-plot)
#     - [CV plot](#CV-plot)

# %%
A = 10
mu = 1.2
sigma = 1
a = 1.677e-11
r = np.arange(0.1, 12.0, 0.04)
G = np.exp( - (r - mu)**2 / (2*sigma**2))
R = a / (r**12)
Vij = R - A*G - R*G
p = -np.log(Vij+0.001)
# Vij = A*((1 + (1/A) * a/(r**12)) * (1 - np.exp(-( r - mu )**2 / (2*sigma**2))) - 1)
TOOLS="crosshair,pan,wheel_zoom,reset,save,box_select"
v = figure(title=('Gaussian Potential with r^12 Potential'), width=900,
           plot_height=400, tools=TOOLS,
           background_fill_color='beige')
v.xaxis.axis_label = 'distance (nm)'
v.yaxis.axis_label = 'Vij'
v.line(r, Vij, line_width=2, color='navy')
output_notebook()
show(v)
# Out:
# /home/kmm5/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:9: RuntimeWarning: invalid value encountered in log
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="20c99433-aae0-445e-ab12-2127970f08b9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="25c4cea9-86de-4100-9b06-a8523fa442c9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("25c4cea9-86de-4100-9b06-a8523fa442c9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("25c4cea9-86de-4100-9b06-a8523fa442c9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '25c4cea9-86de-4100-9b06-a8523fa442c9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2516d61b-bc5a-4e30-8999-47f2b888c9b7":{"roots":{"references":[{"attributes":{"callback":null},"id":"5a25ba20-1e90-49fa-add0-134965803b6d","type":"DataRange1d"},{"attributes":{"axis_label":"distance (nm)","formatter":{"id":"ab2ecaec-0c5d-4e92-a080-3919a9310cd1","type":"BasicTickFormatter"},"plot":{"id":"749717b2-33d8-434e-b356-c6ee090bb245","subtype":"Figure","type":"Plot"},"ticker":{"id":"c16a3205-7fc2-4321-8ce7-d3b91990f982","type":"BasicTicker"}},"id":"b5e47466-da35-4599-b969-e9dea6971e1f","type":"LinearAxis"},{"attributes":{"plot":{"id":"749717b2-33d8-434e-b356-c6ee090bb245","subtype":"Figure","type":"Plot"}},"id":"dca9f933-9bc6-4e74-9908-99796dc17fd1","type":"WheelZoomTool"},{"attributes":{},"id":"c16a3205-7fc2-4321-8ce7-d3b91990f982","type":"BasicTicker"},{"attributes":{"plot":{"id":"749717b2-33d8-434e-b356-c6ee090bb245","subtype":"Figure","type":"Plot"}},"id":"324aa0ee-0082-4ca8-a4f4-41b740187bb4","type":"CrosshairTool"},{"attributes":{},"id":"9c27b3a5-be02-431b-b97f-7e0d959c6610","type":"LinearScale"},{"attributes":{},"id":"ab2ecaec-0c5d-4e92-a080-3919a9310cd1","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"749717b2-33d8-434e-b356-c6ee090bb245","subtype":"Figure","type":"Plot"},"ticker":{"id":"57aa66d3-4b74-4d91-bfba-f0f7906a0bab","type":"BasicTicker"}},"id":"0546c344-7ca9-412c-a175-b89fcf66ef55","type":"Grid"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"757dadfa-8b8c-4a0e-bc8d-e0e08311bd16","type":"Line"},{"attributes":{"plot":{"id":"749717b2-33d8-434e-b356-c6ee090bb245","subtype":"Figure","type":"Plot"}},"id":"b3d82c9a-bd0d-4c20-9f1e-b4e454b42ce4","type":"PanTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[298]},"y":{"__ndarray__":"...","dtype":"float64","shape":[298]}}},"id":"03855bc1-c6af-4236-8c61-3f06a61dd0e9","type":"ColumnDataSource"},{"attributes":{},"id":"19de3ca4-631a-48f9-ba70-63a3ac67f95d","type":"LinearScale"},{"attributes":{"axis_label":"Vij","formatter":{"id":"dc02e0ce-bcfd-47ba-af61-501319353cd9","type":"BasicTickFormatter"},"plot":{"id":"749717b2-33d8-434e-b356-c6ee090bb245","subtype":"Figure","type":"Plot"},"ticker":{"id":"57aa66d3-4b74-4d91-bfba-f0f7906a0bab","type":"BasicTicker"}},"id":"6e8d0887-8f36-4b9f-8bea-68f2cb5e8a7f","type":"LinearAxis"},{"attributes":{"data_source":{"id":"03855bc1-c6af-4236-8c61-3f06a61dd0e9","type":"ColumnDataSource"},"glyph":{"id":"757dadfa-8b8c-4a0e-bc8d-e0e08311bd16","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"811ffa7c-3fd8-4a34-99f7-058afe0c3ff9","type":"Line"},"selection_glyph":null},"id":"bb55a658-a22e-4636-95a5-cd8f1f790065","type":"GlyphRenderer"},{"attributes":{"background_fill_color":{"value":"beige"},"below":[{"id":"b5e47466-da35-4599-b969-e9dea6971e1f","type":"LinearAxis"}],"left":[{"id":"6e8d0887-8f36-4b9f-8bea-68f2cb5e8a7f","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"b5e47466-da35-4599-b969-e9dea6971e1f","type":"LinearAxis"},{"id":"7ccda925-4ad5-4f03-8478-1b0371e443e7","type":"Grid"},{"id":"6e8d0887-8f36-4b9f-8bea-68f2cb5e8a7f","type":"LinearAxis"},{"id":"0546c344-7ca9-412c-a175-b89fcf66ef55","type":"Grid"},{"id":"261e8f7b-c74c-447b-b363-6c65ad0311fc","type":"BoxAnnotation"},{"id":"bb55a658-a22e-4636-95a5-cd8f1f790065","type":"GlyphRenderer"}],"title":{"id":"58c4ff28-1823-40d1-b0fc-c1a2c2fb2ce7","type":"Title"},"tool_events":{"id":"c3d9e4a8-a253-4b9e-9e50-6149ea61a8e5","type":"ToolEvents"},"toolbar":{"id":"96a303d4-9300-49af-8fd6-22094b52e991","type":"Toolbar"},"x_range":{"id":"1ffe8794-0552-4467-9ecd-9e396cdaf9bc","type":"DataRange1d"},"x_scale":{"id":"19de3ca4-631a-48f9-ba70-63a3ac67f95d","type":"LinearScale"},"y_range":{"id":"5a25ba20-1e90-49fa-add0-134965803b6d","type":"DataRange1d"},"y_scale":{"id":"9c27b3a5-be02-431b-b97f-7e0d959c6610","type":"LinearScale"}},"id":"749717b2-33d8-434e-b356-c6e ...

# %%
T = np.arange(80, 170, 10)
kB = 0.008314
boltz_factor = kB*T

# %%
input0 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_80/qval_80.out'
input00 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_90/qval_90.out'
input1 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_100/qval_100.out'
input2 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_110/qval_110.out'
input3 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_120/qval_120.out'
input4 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_130/qval_130.out'
input5 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_140/qval_140.out'
input6 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_150/qval_150.out'
input7 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_160/qval_160.out'

# %%
times0, q_values0 = np.loadtxt(input0, unpack=True)
times00, q_values00 = np.loadtxt(input00, unpack=True)
times1, q_values1 = np.loadtxt(input1, unpack=True)
times2, q_values2 = np.loadtxt(input2, unpack=True)
times3, q_values3 = np.loadtxt(input3, unpack=True)
times4, q_values4 = np.loadtxt(input4, unpack=True)
times5, q_values5 = np.loadtxt(input5, unpack=True)
times6, q_values6 = np.loadtxt(input6, unpack=True)
times7, q_values7 = np.loadtxt(input7, unpack=True)

# %%
# total_residues = max(q_values1)
total_residues = 3240.0

# %% [markdown]
# [Back to Overview](#Overview)

# %% [markdown]
# ### Plot q

# %%
hover = HoverTool(tooltips=[('Q_interface', '$y{1.111}')])
TOOLS="crosshair,pan,wheel_zoom,reset,save,box_select"
p = figure(title=('SBM+DCA interface - 9mer (cuttoff: 8A, t: 10e7)'), width=900,
           plot_height=400, tools=[TOOLS, hover],
           background_fill_color='beige')
p.xaxis.axis_label = 'time'
p.yaxis.axis_label = 'Qint'

p.line(times0, q_values0/total_residues, line_width=2, color='cyan', legend='T=80')
p.line(times00, q_values00/total_residues, line_width=2, color='yellow', legend='T=90')
p.line(times1, q_values1/total_residues, line_width=2, color='navy', legend='T=100')
p.line(times2, q_values2/total_residues, line_width=2, color='violet', legend='T=110')
p.line(times3, q_values3/total_residues, line_width=2, color='red', legend='T=120')
p.line(times4, q_values4/total_residues, line_width=2, color='orange', legend='T=130')
p.line(times5, q_values5/total_residues, line_width=2, color='green', legend='T=140')

p.legend.background_fill_color = "lightgrey"
p.legend.location = "bottom_right"
p.legend.orientation = "horizontal"
p.legend.click_policy="hide"
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ab56b107-2621-4041-9504-9986054d52f9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8ec44773-8ab0-4f71-885c-e2122070d452"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8ec44773-8ab0-4f71-885c-e2122070d452");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8ec44773-8ab0-4f71-885c-e2122070d452");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8ec44773-8ab0-4f71-885c-e2122070d452' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"00a77d52-dcd2-4a53-9c09-a1b103a4605b":{"roots":{"references":[{"attributes":{"background_fill_color":{"value":"lightgrey"},"click_policy":"hide","items":[{"id":"a2a513dd-72d3-44c3-862d-dcc6e52852c2","type":"LegendItem"},{"id":"f25a93d4-2bd9-4f04-b5e1-cd2246d33350","type":"LegendItem"},{"id":"a720ccf4-dd74-461c-9393-d131fab2752b","type":"LegendItem"},{"id":"98897e2a-4447-4c93-b3a7-825377237edd","type":"LegendItem"},{"id":"bcf45292-0fec-487e-8675-20e369b59225","type":"LegendItem"},{"id":"9d00b56c-fb8e-4ebc-9c8c-0abfce08fc48","type":"LegendItem"},{"id":"bd86b120-1101-4130-b5c5-3e11c734be92","type":"LegendItem"}],"location":"bottom_right","orientation":"horizontal","plot":{"id":"bc425440-abe1-4a5d-b56a-cdf17d96db81","subtype":"Figure","type":"Plot"}},"id":"c72891c0-6c89-471c-a384-b8cf7df3ed5e","type":"Legend"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"bd98da3b-7b9a-4df7-aaf6-7175667cd422","type":"Line"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"54009caf-039e-4570-bc69-d5027a382a38","type":"HoverTool"},{"id":"e771ddd7-6d13-4d27-9fbe-916878a6ca39","type":"CrosshairTool"},{"id":"cfd6edd2-777a-400d-bbfd-dc29e812d890","type":"PanTool"},{"id":"eb2831b2-1101-48e5-88b0-5ae749831d2a","type":"WheelZoomTool"},{"id":"9264c2a8-63b9-4d07-b274-52b06b23c28b","type":"ResetTool"},{"id":"3a7b4619-9155-470a-9244-34c7dd128252","type":"SaveTool"},{"id":"ca5adaa5-a1e1-4db3-80e7-c258a5e56927","type":"BoxSelectTool"}]},"id":"132d0973-3c87-494b-b38a-861e9eaf6ca2","type":"Toolbar"},{"attributes":{"plot":{"id":"bc425440-abe1-4a5d-b56a-cdf17d96db81","subtype":"Figure","type":"Plot"}},"id":"cfd6edd2-777a-400d-bbfd-dc29e812d890","type":"PanTool"},{"attributes":{"data_source":{"id":"0c87094e-7c8e-4fdf-a543-58ad6dd7c4b5","type":"ColumnDataSource"},"glyph":{"id":"bd98da3b-7b9a-4df7-aaf6-7175667cd422","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"41ec8cce-f5e6-43ac-b032-5a985ac619be","type":"Line"},"selection_glyph":null},"id":"b5c8a66c-19a7-474e-bc2b-74c9f8d8c62a","type":"GlyphRenderer"},{"attributes":{},"id":"e29a00b7-7c9f-4c09-b5b3-c8ab1896373a","type":"BasicTicker"},{"attributes":{},"id":"8fc2c6b6-f70c-4e7f-8c6c-ad2691b32ca7","type":"BasicTicker"},{"attributes":{},"id":"925dc5c5-57ef-4b85-95f5-a5cf2a08b296","type":"ToolEvents"},{"attributes":{"line_color":{"value":"red"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"6c51994c-2909-43e1-9671-4c4e91b3cfb0","type":"Line"},{"attributes":{"line_color":{"value":"violet"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ce7198ea-e759-4d76-aa8b-3ef618bc0936","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1961]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1961]}}},"id":"56da3aaf-0e49-487c-8222-d8884299080b","type":"ColumnDataSource"},{"attributes":{"axis_label":"Qint","formatter":{"id":"7a4def6c-faba-4092-b89d-9a037a0c2532","type":"BasicTickFormatter"},"plot":{"id":"bc425440-abe1-4a5d-b56a-cdf17d96db81","subtype":"Figure","type":"Plot"},"ticker":{"id":"8fc2c6b6-f70c-4e7f-8c6c-ad2691b32ca7","type":"BasicTicker"}},"id":"53011931-f863-413e-8d8a-10a3c612ac07","type":"LinearAxis"},{"attributes":{"data_source":{"id":"2b87d56f-2221-43de-8892-2c6d9f9e1443","type":"ColumnDataSource"},"glyph":{"id":"b183addb-d989-45f2-9462-5ac48a1a0137","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2d77deab-2377-47f8-b77b-dbbbaa2c5e37","type":"Line"},"selection_glyph":null},"id":"325fb259-6e4d-4d98-a58d-b17d2c75fe37","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1961]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1961]}}},"id":"c177f360-69fe-4ccd-a75e-5d92a71372ff","type":"C ...

# %% [markdown]
# ### Q Histogram

# %% [markdown]
# [Back to Overview](#Overview)

# %%
qhist_t80, qedges_t80 = np.histogram(q_values0/total_residues, density=True, bins=50)
qhist_t90, qedges_t90 = np.histogram(q_values00/total_residues, density=True, bins=50)
qhist_t100, qedges_t100 = np.histogram(q_values1/total_residues, density=True, bins=50)
qhist_t110, qedges_t110 = np.histogram(q_values2/total_residues, density=True, bins=50)
qhist_t120, qedges_t120 = np.histogram(q_values3/total_residues, density=True, bins=50)
qhist_t130, qedges_t130 = np.histogram(q_values4/total_residues, density=True, bins=50)
qhist_t140, qedges_t140 = np.histogram(q_values5/total_residues, density=True, bins=50)
qhist_t150, qedges_t150 = np.histogram(q_values6/total_residues, density=True, bins=50)
qhist_t160, qedges_t160 = np.histogram(q_values7/total_residues, density=True, bins=50)

# %%
TOOLS="crosshair,pan,wheel_zoom,reset,save,box_select"
hq = figure(title=('Qint histogram'), width=900,
           plot_height=400, tools=TOOLS,
           background_fill_color='beige')

hq.xaxis.axis_label = 'Qint'
hq.yaxis.axis_label = 'Counts'

hq.quad(top=qhist_t80, bottom=0, left=qedges_t80[:-1], right=qedges_t80[1:],
        fill_color="cyan", line_color="#033649", alpha=0.5, legend="T=80")
hq.quad(top=qhist_t90, bottom=0, left=qedges_t90[:-1], right=qedges_t90[1:],
        fill_color="yellow", line_color="#033649", alpha=0.5, legend="T=90")
hq.quad(top=qhist_t100, bottom=0, left=qedges_t100[:-1], right=qedges_t100[1:],
        fill_color="navy", line_color="#033649", legend="T=100")
hq.quad(top=qhist_t110, bottom=0, left=qedges_t110[:-1], right=qedges_t110[1:],
        fill_color="violet", line_color="black", alpha=0.5, legend="T=110")
hq.quad(top=qhist_t120, bottom=0, left=qedges_t120[:-1], right=qedges_t120[1:],
        fill_color="red", line_color="#033649", alpha=0.5, legend="T=120")
hq.quad(top=qhist_t130, bottom=0, left=qedges_t130[:-1], right=qedges_t130[1:],
        fill_color="teal", line_color="#033649", alpha=0.6, legend="T=130")
hq.quad(top=qhist_t140, bottom=0, left=qedges_t140[:-1], right=qedges_t140[1:],
        fill_color="green", line_color="#033649", alpha=0.5, legend="T=140")
hq.quad(top=qhist_t150, bottom=0, left=qedges_t150[:-1], right=qedges_t150[1:],
        fill_color="blue", line_color="#033649", alpha=0.5, legend="T=150")
hq.quad(top=qhist_t160, bottom=0, left=qedges_t160[:-1], right=qedges_t160[1:],
        fill_color="orange", line_color="#033649", alpha=0.5, legend="T=160")

hq.legend.click_policy="hide"
output_notebook()
show(hq)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="69364da1-aa67-4e75-bfd0-75b8a26a8259">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1224fd59-c5b8-4612-9391-343ef88185ed"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("1224fd59-c5b8-4612-9391-343ef88185ed");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1224fd59-c5b8-4612-9391-343ef88185ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1224fd59-c5b8-4612-9391-343ef88185ed' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cebd61c5-2102-414c-ad57-2c20040217de":{"roots":{"references":[{"attributes":{"label":{"value":"T=150"},"renderers":[{"id":"8be62350-1ed4-4982-9d7f-f08fe8c4ef3d","type":"GlyphRenderer"}]},"id":"a6c39a9a-678b-4138-a804-f473da8d7ed2","type":"LegendItem"},{"attributes":{"data_source":{"id":"e049a169-22c3-400d-a839-8cd21d04b2e7","type":"ColumnDataSource"},"glyph":{"id":"7eb4064e-1fe0-49db-a18b-25ae778401ea","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"d8ffa19f-14ed-4423-a26b-02470cdee528","type":"Quad"},"selection_glyph":null},"id":"dd792c20-7e1b-46aa-a58a-e134abfe7f0b","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c01032cf-02f4-454d-92e9-0e65a6f48753","type":"ColumnDataSource"},"glyph":{"id":"3f291d4f-1ce3-4b91-9c36-5752e1df85ea","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"690bbac6-2b52-4ac3-ad49-afe3c84e67e3","type":"Quad"},"selection_glyph":null},"id":"a26e2c88-9175-4a89-8625-07a86f26fcc3","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"be351c73-8703-445c-a2e7-06231b341cda","type":"ColumnDataSource"},{"attributes":{"label":{"value":"T=130"},"renderers":[{"id":"a26e2c88-9175-4a89-8625-07a86f26fcc3","type":"GlyphRenderer"}]},"id":"a0a60029-2249-4af4-8259-ac7a55ff57ee","type":"LegendItem"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"615c100f-fa5a-4bbb-8e0b-186c321a7214","type":"Quad"},{"attributes":{},"id":"0a31676d-9c16-4a0d-ba7b-edf9539b0d29","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"T=90"},"renderers":[{"id":"b2de8f83-99ef-4154-afa3-b6b15731ca3b","type":"GlyphRenderer"}]},"id":"78c11d91-22c2-4628-9f91-be3542f1dfba","type":"LegendItem"},{"attributes":{"data_source":{"id":"0b5c810a-8d92-499e-9f9b-18372ef4b37f","type":"ColumnDataSource"},"glyph":{"id":"f5e20fb8-879f-474c-a22e-103dda5d0b80","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e2e213c5-b7c2-4279-8904-7a6f6244f803","type":"Quad"},"selection_glyph":null},"id":"b2de8f83-99ef-4154-afa3-b6b15731ca3b","type":"GlyphRenderer"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.6},"fill_color":{"value":"teal"},"left":{"field":"left"},"line_alpha":{"value":0.6},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"3f291d4f-1ce3-4b91-9c36-5752e1df85ea","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"27c94f9d-accb-47cd-bda2-dda49f17a589","type":"Quad"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.5},"fill_color":{"value":"yellow"},"left":{"field":"left"},"line_alpha":{"value":0.5},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"f5e20fb8-879f-474c-a22e-103dda5d0b80","type":"Quad"},{"attributes":{"label":{"value":"T=100"},"renderers":[{"id":"5d65efaa-b366-4c8d-a134-274c89834a19","type":"GlyphRenderer"}]},"id":"52fc307f-2b1b-408a-ae81-f3c70cab166f","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5ca0e818-9ff3-471e-9c62-c179be53d0b6","type":"CrosshairTool"},{"id":"7a9e474a-c9f7-4bb5-aeb6-726e1400c313","type":"PanTool"},{"id":"d16d9e4d-eac1-43b9-8748-430294dac488","type":"WheelZoomTool"},{"id":"00c2a7ff-ab6b-4a44-b048-3f505735232b","type":"ResetTool"},{"id":"cdc8492f-c736-48ad-90ad-d9a11e687795","type":"SaveTool"} ...

# %% [markdown]
# ### Plot distance histogram

# %% [markdown]
# [Back to Overview](#Overview)

# %%
input_dist0 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p1_120.xvg'
input_dist00 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p2_120.xvg'
input_dist1 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p3_120.xvg'
input_dist2 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p4_120.xvg'
input_dist3 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p5_120.xvg'
input_dist4 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p6_120.xvg'
input_dist5 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p7_120.xvg'
input_dist6 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p8_120.xvg'
input_dist7 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p9_120.xvg'
input_dist8 = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/run_54int_120_A5_w1/dist_p10_120.xvg'

# %%
time_t80, dist_t80 = np.loadtxt(input_dist0, usecols=(0,1), unpack=True, skiprows=22)
time_t90, dist_t90 = np.loadtxt(input_dist00, usecols=(0,1), unpack=True, skiprows=22)
time_t100, dist_t100 = np.loadtxt(input_dist1, usecols=(0,1), unpack=True, skiprows=22)
time_t110, dist_t110 = np.loadtxt(input_dist2, usecols=(0,1), unpack=True, skiprows=22)
time_t120, dist_t120 = np.loadtxt(input_dist3, usecols=(0,1), unpack=True, skiprows=22)
time_t130, dist_t130 = np.loadtxt(input_dist4, usecols=(0,1), unpack=True, skiprows=22)
time_t140, dist_t140 = np.loadtxt(input_dist5, usecols=(0,1), unpack=True, skiprows=22)
time_t150, dist_t150 = np.loadtxt(input_dist6, usecols=(0,1), unpack=True, skiprows=22)
time_t160, dist_t160 = np.loadtxt(input_dist7, usecols=(0,1), unpack=True, skiprows=22)
time_t170, dist_t170 = np.loadtxt(input_dist8, usecols=(0,1), unpack=True, skiprows=22)

# %%
hist_t80, edges_t80 = np.histogram(dist_t80, density=True, bins=50)
hist_t90, edges_t90 = np.histogram(dist_t90, density=True, bins=50)
hist_t100, edges_t100 = np.histogram(dist_t100, density=True, bins=50)
hist_t110, edges_t110 = np.histogram(dist_t110, density=True, bins=50)
hist_t120, edges_t120 = np.histogram(dist_t120, density=True, bins=50)
hist_t130, edges_t130 = np.histogram(dist_t130, density=True, bins=50)
hist_t140, edges_t140 = np.histogram(dist_t140, density=True, bins=50)
hist_t150, edges_t150 = np.histogram(dist_t150, density=True, bins=50)
hist_t160, edges_t160 = np.histogram(dist_t160, density=True, bins=50)
hist_t170, edges_t170 = np.histogram(dist_t170, density=True, bins=50)

# %%
second_mom = scipy.stats.moment(dist_t80, moment=2)
second_mom
# Out:
# 0.17880805836149166

# %% [markdown]
# [Back to Overview](#Overview)

# %%
TOOLS="crosshair,pan,wheel_zoom,reset,save,box_select"
h = figure(title=('DCA interfacial pair distance flucuations (r0 = 17A)'), width=900,
           plot_height=400, tools=TOOLS,
           background_fill_color='beige')

h.xaxis.axis_label = 'Distance (nm)'
h.yaxis.axis_label = 'Counts'

# h.line(time_t100, dist_t100, line_width=2, color='navy')
# h.line(time_t110, dist_t110, line_width=2, color='violet')
# h.line(time_t120, dist_t120, line_width=2, color='red')

h.quad(top=hist_t80, bottom=0, left=edges_t80[:-1], right=edges_t80[1:],
        fill_color="cyan", line_color="#033649", alpha=0.5, legend="p1")
h.quad(top=hist_t90, bottom=0, left=edges_t90[:-1], right=edges_t90[1:],
        fill_color="yellow", line_color="#033649", alpha=0.5, legend="p2")
h.quad(top=hist_t100, bottom=0, left=edges_t100[:-1], right=edges_t100[1:],
        fill_color="navy", line_color="#033649", legend="p3")
h.quad(top=hist_t110, bottom=0, left=edges_t110[:-1], right=edges_t110[1:],
        fill_color="violet", line_color="black", alpha=0.5, legend="p4")
h.quad(top=hist_t120, bottom=0, left=edges_t120[:-1], right=edges_t120[1:],
        fill_color="red", line_color="#033649", alpha=0.5, legend="p5")
h.quad(top=hist_t130, bottom=0, left=edges_t130[:-1], right=edges_t130[1:],
        fill_color="orange", line_color="#033649", alpha=0.5, legend="p6")
h.quad(top=hist_t140, bottom=0, left=edges_t140[:-1], right=edges_t140[1:],
        fill_color="green", line_color="#033649", alpha=0.5, legend="p7")
h.quad(top=hist_t150, bottom=0, left=edges_t150[:-1], right=edges_t150[1:],
        fill_color="coral", line_color="#033649", alpha=0.5, legend="p8")
h.quad(top=hist_t160, bottom=0, left=edges_t160[:-1], right=edges_t160[1:],
        fill_color="teal", line_color="#033649", alpha=0.5, legend="p9")
h.quad(top=hist_t170, bottom=0, left=edges_t170[:-1], right=edges_t170[1:],
        fill_color="purple", line_color="#033649", alpha=0.5, legend="p10")

h.legend.click_policy="hide"
output_notebook()
show(h)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="375f0995-d53f-415f-9d1f-c9c6ad741d88">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="0d055dae-2e18-4c08-93af-842cc4b14b98"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("0d055dae-2e18-4c08-93af-842cc4b14b98");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0d055dae-2e18-4c08-93af-842cc4b14b98");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0d055dae-2e18-4c08-93af-842cc4b14b98' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4dd94d23-5eb3-4c16-892a-4d3fef7f073e":{"roots":{"references":[{"attributes":{"label":{"value":"p5"},"renderers":[{"id":"b74e515c-363a-4576-84d7-470c55c8e016","type":"GlyphRenderer"}]},"id":"1479c162-8332-48ac-b501-8915083471aa","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"6eb68360-525d-4100-a43e-dd73212bb63f","type":"ColumnDataSource"},{"attributes":{},"id":"d8002b1f-e7be-4d1f-b4a1-af3f30abf2bd","type":"BasicTickFormatter"},{"attributes":{"label":{"value":"p7"},"renderers":[{"id":"85679dc0-e4e6-45bb-8ae7-144d6bf0ac65","type":"GlyphRenderer"}]},"id":"9f6047e1-7ba0-4025-929e-1bb8553e33c4","type":"LegendItem"},{"attributes":{"callback":null},"id":"3acb8b1a-430a-4c5d-8583-e3d14c84bdd5","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"fc848378-cd7e-48b4-9f77-0e8798e7aecf","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"f501d108-702f-41fc-ad52-b3f1c2f88ae4","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"d905d9c9-3920-41ce-971a-d5a468ac0436","type":"ColumnDataSource"},{"attributes":{"label":{"value":"p4"},"renderers":[{"id":"eefc84b3-798e-464b-b34e-faa9586bd47b","type":"GlyphRenderer"}]},"id":"7753fe1e-fc3c-4aef-bd29-83cdca790ecc","type":"LegendItem"},{"attributes":{"data_source":{"id":"4418499b-0b83-4bd1-a17a-488cacd64da5","type":"ColumnDataSource"},"glyph":{"id":"c70ecb40-8ddd-4c65-b440-2b8b73bf4916","type":"Quad"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"498e70ef-3c02-4e31-8c4d-328ea503549b","type":"Quad"},"selection_glyph":null},"id":"84e9fdb0-cbe4-4c40-ab65-74f2b22b3158","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"91e41edd-49d0-4924-9e97-b50009b04e25","type":"ColumnDataSource"},{"attributes":{"axis_label":"Distance (nm)","formatter":{"id":"d8002b1f-e7be-4d1f-b4a1-af3f30abf2bd","type":"BasicTickFormatter"},"plot":{"id":"667dc9ff-04ff-4f30-861e-a3b825deb688","subtype":"Figure","type":"Plot"},"ticker":{"id":"214fda70-e0d0-4b54-a5a3-166a7ed5201a","type":"BasicTicker"}},"id":"4534b045-42fb-4814-b64d-07f2e327f883","type":"LinearAxis"},{"attributes":{},"id":"0eb23b3d-a0e6-4b16-8ecc-4cdb97288964","type":"LinearScale"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"de7fc906-18f9-47cd-aedf-e0de185e0dfe","type":"Quad"},{"attributes":{"callback":null,"overlay":{"id":"ec211072-b615-4d51-b8e6-453eb9d26963","type":"BoxAnnotation"},"plot":{"id":"667dc9ff-04ff-4f30-861e-a3b825deb688","subtype":"Figure","type":"Plot"},"renderers":[{"id":"188e4de8-8e63-4e12-8f9c-0ae8d32b0fc3","type":"GlyphRenderer"},{"id":"f7b88df6-8953-4717-99db-f1299e73f891","type":"GlyphRenderer"},{"id":"483880fd-f79a-45f7-bca7-349617c5851c","type":"GlyphRenderer"},{"id":"eefc84b3-798e-464b-b34e-faa9586bd47b","type":"GlyphRenderer"},{"id":"b74e515c-363a-4576-84d7-470c55c8e016","type":"GlyphRenderer"},{"id":"a41b67ca-7fc6-4141-97b5-24424f7ff4a6","type":"GlyphRenderer"},{"id":"85 ...

# %% [markdown]
# ## Wham Results

# %% [markdown]
# ### F vs Q plot

# %% [markdown]
# [Back to Overview](#Overview)

# %%
free_file_800 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/800"
free_file_900 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/900"
free_file_1000 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1000"
free_file_1100 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1100"
free_file_1200 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1200"
free_file_1300 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1300"
free_file_1400 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1400"
free_file_1500 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1500"
free_file_1600 = "/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/free/1600"
q_value_800, free_energy_800 = np.loadtxt(free_file_800, usecols=(0,1), unpack=True)
q_value_900, free_energy_900 = np.loadtxt(free_file_900, usecols=(0,1), unpack=True)
q_value_1000, free_energy_1000 = np.loadtxt(free_file_1000, usecols=(0,1), unpack=True)
q_value_1100, free_energy_1100 = np.loadtxt(free_file_1100, usecols=(0,1), unpack=True)
q_value_1200, free_energy_1200 = np.loadtxt(free_file_1200, usecols=(0,1), unpack=True)
q_value_1300, free_energy_1300 = np.loadtxt(free_file_1300, usecols=(0,1), unpack=True)
q_value_1400, free_energy_1400 = np.loadtxt(free_file_1400, usecols=(0,1), unpack=True)
q_value_1500, free_energy_1500 = np.loadtxt(free_file_1500, usecols=(0,1), unpack=True)
q_value_1600, free_energy_1600 = np.loadtxt(free_file_1600, usecols=(0,1), unpack=True)

# %%
hover = HoverTool(tooltips=[('Q_interface', '$y{1.111}')])
TOOLS="crosshair,pan,wheel_zoom,reset,save,box_select"
p2 = figure(title=('F(Q) vs. Q'), width=900,
           plot_height=400, tools=[TOOLS, hover],
           background_fill_color='beige')
p2.xaxis.axis_label = 'Qint'
p2.yaxis.axis_label = 'F(Q)'

p2.line(q_value_800/total_residues, free_energy_800/(10*boltz_factor[0]),
        line_width=2, color='purple', legend='T:80')
p2.line(q_value_900/total_residues, free_energy_900/(10*boltz_factor[1]),
        line_width=2, color='navy', legend='T:90')
p2.line(q_value_1000/total_residues, free_energy_1000/(10*boltz_factor[2]),
        line_width=2, color='cyan', legend='T:100')
p2.line(q_value_1100/total_residues, free_energy_1100/(10*boltz_factor[3]),
        line_width=2, color='yellow', legend='T:110')
p2.line(q_value_1200/total_residues, free_energy_1200/(10*boltz_factor[4]),
        line_width=2, color='green', legend='T:120')
p2.line(q_value_1300/total_residues, free_energy_1300/(10*boltz_factor[5]),
        line_width=2, color='red', legend='T:130')
p2.line(q_value_1400/total_residues, free_energy_1400/(10*boltz_factor[6]),
        line_width=2, color='blue', legend='T:140')
p2.line(q_value_1500/total_residues, free_energy_1500/(10*boltz_factor[7]),
        line_width=2, color='orange', legend='T:150')
p2.line(q_value_1600/total_residues, free_energy_1600/(10*boltz_factor[8]),
        line_width=2, color='violet', legend='T:160')

p2.legend.background_fill_color = "lightgrey"
p2.legend.location = "top_right"
p2.legend.click_policy="hide"
output_notebook()
show(p2)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="89ec44cd-776a-4758-aa9f-3e93bf7ef2f2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8ab1c9d0-a374-4be7-8195-79d6f144cec5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8ab1c9d0-a374-4be7-8195-79d6f144cec5");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8ab1c9d0-a374-4be7-8195-79d6f144cec5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8ab1c9d0-a374-4be7-8195-79d6f144cec5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a463363c-c467-4a52-b8e0-dc0a60aaec18":{"roots":{"references":[{"attributes":{"data_source":{"id":"7ad4d543-fd38-4eed-9fc0-1770fad251ce","type":"ColumnDataSource"},"glyph":{"id":"72db0a1b-aed9-4807-9e68-ec4969771ddd","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"7e54f9f4-4d5c-476a-96f7-55364ca51589","type":"Line"},"selection_glyph":null},"id":"ad4a84ac-4288-4a8a-a94a-c7924c802dd3","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"173e2a9c-a17c-4fb6-8fbe-08b526a9df1b","subtype":"Figure","type":"Plot"},"tooltips":[["Q_interface","$y{1.111}"]]},"id":"f93d0113-de55-4ed9-8b91-b5644e118301","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1090]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1090]}}},"id":"d296f178-92ea-4d08-ac97-6904ab151527","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"orange"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"16f55500-32c4-4f64-a0b5-6a0d44ce3f65","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"a1a322d2-a355-4e8d-bdf3-8cbbbf6ba99a","type":"Line"},{"attributes":{"plot":null,"text":"F(Q) vs. Q"},"id":"d8e67b6b-5753-4e96-9424-c1a87609a526","type":"Title"},{"attributes":{"callback":null},"id":"7b2a4a60-354d-4a02-84a2-c57e6e7c5c8e","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1090]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1090]}}},"id":"b257f531-12cc-452a-abf5-7f351d29abec","type":"ColumnDataSource"},{"attributes":{"label":{"value":"T:160"},"renderers":[{"id":"ec0a5dd1-d83d-4c76-bb04-e2f92caa00a3","type":"GlyphRenderer"}]},"id":"ef4e54c1-a0ff-4f67-903d-8312f96de13f","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"d0809f0d-7dae-4dc0-a525-84c1be57cd14","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"173e2a9c-a17c-4fb6-8fbe-08b526a9df1b","subtype":"Figure","type":"Plot"}},"id":"61a49e5e-fdd7-4f11-a97d-bc464312dd7b","type":"SaveTool"},{"attributes":{"line_color":{"value":"navy"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"72db0a1b-aed9-4807-9e68-ec4969771ddd","type":"Line"},{"attributes":{"data_source":{"id":"b257f531-12cc-452a-abf5-7f351d29abec","type":"ColumnDataSource"},"glyph":{"id":"fafc0c01-93ab-45cd-a6e5-c57082690195","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"a1a322d2-a355-4e8d-bdf3-8cbbbf6ba99a","type":"Line"},"selection_glyph":null},"id":"32658f87-a5a6-49ef-9aee-ba4ab4f75056","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1090]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1090]}}},"id":"7ad4d543-fd38-4eed-9fc0-1770fad251ce","type":"ColumnDataSource"},{"attributes":{},"id":"7340f418-f856-43e8-ab64-8657dafd6faa","type":"BasicTicker"},{"attributes":{},"id":"ee4711bd-e07d-4c1b-93b0-4d04db8bb9dd","type":"ToolEvents"},{"attributes":{"line_color":{"value":"purple"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c05ffe8e-8e95-447c-b397-0f2a76a30f42","type":"Line"},{"attributes":{"data_source":{"id":"d296f178-92ea-4d08-ac97-6904ab151527","type":"ColumnDataSource"},"glyph":{"id":"7a9755f3-1685-44ba-bd6a-72878b452604","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"e82f805c-636f-4ad9-bf9b-860c74c37c88","type":"Line"},"selection_glyph":null},"id":"9107f78c-a307-4bcd-a931-95d9e7e ...

# %% [markdown]
# ## CV plot

# %% [markdown]
# [Back to Overview](#Overview)

# %%
cv_file = '/home/kmm5/actin/sbm/oda9mer/results_top45/step10e7/WHAM/cv'
temp, cv = np.loadtxt(cv_file, usecols=(0,1), unpack=True)

# %%
TOOLS="crosshair,pan,wheel_zoom,reset,save,box_select"
p3 = figure(title=('CV'), width=900,
           plot_height=400, tools=TOOLS,
           background_fill_color='beige')
p3.xaxis.axis_label = 'T'
p3.yaxis.axis_label = 'CV(T)'
p3.line(temp[:8], cv[:8], line_width=2, color='purple')
output_notebook()
show(p3)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="29a189c1-f3e8-4962-a4cd-1df645b70679">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e2e11c8-a18d-4a38-ac61-cf335c62de97"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6e2e11c8-a18d-4a38-ac61-cf335c62de97");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e2e11c8-a18d-4a38-ac61-cf335c62de97");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e2e11c8-a18d-4a38-ac61-cf335c62de97' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"eb39fe90-1e8e-4871-8686-96851be01908":{"roots":{"references":[{"attributes":{},"id":"0b731258-e77b-41c1-aea7-88a93e2fb23d","type":"ToolEvents"},{"attributes":{},"id":"11da7f2d-a6bf-4083-8a8b-45a4f29bfe0e","type":"BasicTickFormatter"},{"attributes":{"axis_label":"CV(T)","formatter":{"id":"11da7f2d-a6bf-4083-8a8b-45a4f29bfe0e","type":"BasicTickFormatter"},"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"85b8481e-696e-4049-87d9-28cdd425d461","type":"BasicTicker"}},"id":"8dcc1a7f-4dcc-4954-a372-55b245702ff7","type":"LinearAxis"},{"attributes":{"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"}},"id":"638cf680-db3d-4a62-b501-b356fcc7ef64","type":"ResetTool"},{"attributes":{"line_color":{"value":"purple"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"49714ebe-956d-4642-ac56-d9b9a669a543","type":"Line"},{"attributes":{"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"83ba4155-f3f6-4de6-95a1-27a1751e064b","type":"BasicTicker"}},"id":"e9268c70-a809-4a89-a6d4-46a7ef54e5f2","type":"Grid"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"257fc764-46a3-4c7a-8d19-d66fc23793a8","type":"CrosshairTool"},{"id":"bd0f194c-7e86-49ac-a838-eccdd4f8fc16","type":"PanTool"},{"id":"39ab804e-5de0-444b-80a6-9e185c03c745","type":"WheelZoomTool"},{"id":"638cf680-db3d-4a62-b501-b356fcc7ef64","type":"ResetTool"},{"id":"cb605007-c564-4260-8212-53a3385b2a7c","type":"SaveTool"},{"id":"c1bea23d-2e8c-473a-9ef2-9e96c957ccf1","type":"BoxSelectTool"}]},"id":"3249f659-2f23-46bd-9229-389eefaf35d8","type":"Toolbar"},{"attributes":{"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"}},"id":"257fc764-46a3-4c7a-8d19-d66fc23793a8","type":"CrosshairTool"},{"attributes":{"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"}},"id":"39ab804e-5de0-444b-80a6-9e185c03c745","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"}},"id":"cb605007-c564-4260-8212-53a3385b2a7c","type":"SaveTool"},{"attributes":{"axis_label":"T","formatter":{"id":"21284ff7-8316-4a60-924a-407e04408c1d","type":"BasicTickFormatter"},"plot":{"id":"0d862db8-8310-4015-94d1-237fad24b0d2","subtype":"Figure","type":"Plot"},"ticker":{"id":"83ba4155-f3f6-4de6-95a1-27a1751e064b","type":"BasicTicker"}},"id":"a02cd057-7309-43c3-8a9d-f50d8bd07915","type":"LinearAxis"},{"attributes":{},"id":"85b8481e-696e-4049-87d9-28cdd425d461","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"248fd7af-7870-4bcc-82de-869190bb19d1","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"107c7c0b-aebf-40ec-ab7c-e9e696ec704d","type":"DataRange1d"},{"attributes":{"background_fill_color":{"value":"beige"},"below":[{"id":"a02cd057-7309-43c3-8a9d-f50d8bd07915","type":"LinearAxis"}],"left":[{"id":"8dcc1a7f-4dcc-4954-a372-55b245702ff7","type":"LinearAxis"}],"plot_height":400,"plot_width":900,"renderers":[{"id":"a02cd057-7309-43c3-8a9d-f50d8bd07915","type":"LinearAxis"},{"id":"e9268c70-a809-4a89-a6d4-46a7ef54e5f2","type":"Grid"},{"id":"8dcc1a7f-4dcc-4954-a372-55b245702ff7","type":"LinearAxis"},{"id":"cd935c0d-c180-416d-b8fc-98000a47e5d6","type":"Grid"},{"id":"248fd7af-7870-4bcc-82de-869190bb19d1","type":"BoxAnnotation"},{"id":"df2d7171-5a2b-4485-9a5b-401eccb65f06","type":"GlyphRenderer"}],"title":{"id":"2063856e-a5a1-45ef-92eb-f8b133ca195a","type":"Title"},"tool_events":{"id":"0b731258-e77b-41c1-aea7-88a93e2fb23d","type":"ToolEvents"},"toolbar":{"id":"3249f659 ...

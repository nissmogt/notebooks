# %%
#Import stuff
# %matplotlib inline
from bokeh.plotting import figure, show, output_notebook
# from bokeh.charts import Scatter, output_file, show
from bkcharts import Scatter, output_file, show
from bokeh.palettes import Spectral4
from bokeh.layouts import gridplot
from bokeh.models import HoverTool

import matplotlib
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Overview

# %%
factin_dir = "sbm/pdb_maps_8A/all_pdb_monomer_8A.contacts"
factin_inter_dir = "sbm/pdb_maps_8A/all_pdb_interface_8A.contacts"
gactin_dir = "gactin/8A/cutoff/gactin_ca_8A.contacts"
dca_dir = "plmDCA/pfam/pfam30/act_pfam_f50_mapped.contacts"
# dca_dir = "plmDCA/cytoplasm/from_actin-actin_subseq/actinx2_09-25-17/actx2_ranked.fn"

# %%
Fi, Fj = np.loadtxt(factin_dir, unpack=True)
Ii, Ij = np.loadtxt(factin_inter_dir, unpack=True)
Gi, Gj = np.loadtxt(gactin_dir, unpack=True)
pi, pj = np.loadtxt(dca_dir, usecols=(0,1), unpack=True)

# %%
N = 200
hover = HoverTool(tooltips=[('$Res i, $Res j', '$x{0}, $y{0}')])
TOOLS = "crosshair, pan, wheel_zoom, reset, save, box_select"
p = figure(title=('Top %d DCA' % N), 
           width=705, plot_height=500, tools=[TOOLS, hover])
p.square(Fi, Fj, 
         legend='F-actin Monomer', alpha=0.5, color='navy')
p.square(Ii, Ij, 
         legend='F-actin Interface', alpha=0.5, color='green')
# p.scatter(Gi, Gj, 
#           legend='G-actin Monomer', alpha=0.5, color='green')
p.scatter(pi[:N], pj[:N], 
          legend='DCA', alpha=0.8, color='orangered', 
          line_width=1, size=4)
p.legend.location="bottom_right"
p.legend.click_policy="hide"
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="628a53f8-3f48-4524-a561-f380adadfdc9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="65c007dd-32e0-4fdf-88ec-6569bc16cb48"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("65c007dd-32e0-4fdf-88ec-6569bc16cb48");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("65c007dd-32e0-4fdf-88ec-6569bc16cb48");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '65c007dd-32e0-4fdf-88ec-6569bc16cb48' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4c57eea7-5605-4a70-88ce-32b2e5b28c79":{"roots":{"references":[{"attributes":{"label":{"value":"DCA"},"renderers":[{"id":"63e1b3f2-6418-45ab-9a2e-48b24aee3379","type":"GlyphRenderer"}]},"id":"3f566226-d3aa-4631-b0b2-ba7d0ec07bca","type":"LegendItem"},{"attributes":{"callback":null,"plot":{"id":"fefa2f40-91bb-4e63-8bd4-f666d5dda84d","subtype":"Figure","type":"Plot"},"tooltips":[["$Res i, $Res j","$x{0}, $y{0}"]]},"id":"a8bb091e-588e-4aeb-be7d-d359d087adb6","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"navy"},"line_alpha":{"value":0.5},"line_color":{"value":"navy"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb287412-f597-41d6-9721-36462c512b26","type":"Square"},{"attributes":{"plot":{"id":"fefa2f40-91bb-4e63-8bd4-f666d5dda84d","subtype":"Figure","type":"Plot"}},"id":"0f0a5213-ff69-4442-b047-82a327da127f","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[200]},"y":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"484afd02-c8ec-43bc-88a9-4b561bda6aff","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Top 200 DCA"},"id":"3c09070b-ddbd-4fc3-b25d-d772e48257e9","type":"Title"},{"attributes":{},"id":"f93a46e5-cadc-4678-89be-8143475bbd37","type":"BasicTickFormatter"},{"attributes":{},"id":"fb137cf3-edac-4dbc-88f4-75bd53a9792d","type":"ToolEvents"},{"attributes":{},"id":"3f48646e-13e1-40b5-ac23-3639265e32f1","type":"BasicTicker"},{"attributes":{"data_source":{"id":"71725da8-3303-4489-a742-060dd344d60b","type":"ColumnDataSource"},"glyph":{"id":"bb287412-f597-41d6-9721-36462c512b26","type":"Square"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"85dc2fd0-2f8e-46c6-b44f-db6fb607c3c7","type":"Square"},"selection_glyph":null},"id":"c4fe9011-872b-4ddc-af46-3170e4d2b4d8","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"6e1ba883-445b-4ba3-ad60-afb7c44bbae2","type":"DataRange1d"},{"attributes":{},"id":"6afb212b-c7d1-44f5-8450-3045c429ad3c","type":"LinearScale"},{"attributes":{},"id":"8e49679b-af08-4a96-a8df-797f3ab4b950","type":"LinearScale"},{"attributes":{"plot":{"id":"fefa2f40-91bb-4e63-8bd4-f666d5dda84d","subtype":"Figure","type":"Plot"}},"id":"e07eb7fc-e940-4a69-9c16-60ed1a411d11","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a8bb091e-588e-4aeb-be7d-d359d087adb6","type":"HoverTool"},{"id":"7da81aaf-6730-48c6-aba5-bbb3058d0fc6","type":"CrosshairTool"},{"id":"b1dac8f6-75e0-48f1-bcb2-b994b4521c6e","type":"PanTool"},{"id":"0f0a5213-ff69-4442-b047-82a327da127f","type":"WheelZoomTool"},{"id":"e07eb7fc-e940-4a69-9c16-60ed1a411d11","type":"ResetTool"},{"id":"331af041-fd0e-40b5-97f2-0c12f1207784","type":"SaveTool"},{"id":"32b173f3-ddeb-4335-aeef-f94ff1bc51a8","type":"BoxSelectTool"}]},"id":"de734fd8-2e3e-435c-83f2-b398c54690ad","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[643]},"y":{"__ndarray__":"...","dtype":"float64","shape":[643]}}},"id":"60dd8f80-3e50-4752-aae3-1f2e4badd2a5","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7bde2e36-cbb1-40e9-9c4d-58d07a376f5c","type":"BoxAnnotation"},{"attributes":{},"id":"00e68c97-74cb-4290-97af-20145a322d2a","type":"BasicTickFormatter"},{"attributes":{"click_policy":"hide","items":[{"id":"afa1c77d-7934-4aae-9d18-1f1b59d13608","type":"LegendItem"},{"id":"2a237f36-6873-4af4-9aaa-b82ba90c998a","type":"LegendItem"},{"id":"3f566226-d3aa-4631-b0b2-ba7d0ec07bca","type":"LegendItem"}],"location":"bottom_right","plot":{"id":"fefa2f40 ...

# %% [markdown]
# [Back to top](#Overview)
